# %% [markdown]
#  # Premiers exercices

# %%
print("Hello world")
# Out:
# Hello world

# %%
print("Analyse Bourse")
# Out:
# Analyse Bourse

# %% [markdown]
# # Let's go learning PYTHON

# %%
# Ceci est un commentaire dans la cellule de code
# Python est un programmation orienté OBJET. On définit les variables
name = "Ajla"
print(name)
# Out:
# Ajla

# %%
# sinon j'appelle la variable
name
# Out:
# 'Ajla'

# %%
name = "Thomas"
name
# la dernière définition de variable l'emporte
# Out:
# 'Thomas'

# %%
#Pour les chiffres on a 
age = 26 # ce sont des INTERGER donc les nombres entiers
print(age)
# Out:
# 26

# %%
pi = 3.14159
pi
# Out:
# 3.14159

# %%
# un dictionnaire c'est CLE VALEUR
prices = {
    "APPL" : 255.52,
    "GOOGL" : 333.33,
    "TSLA" : 437.43
}

# %%
prices
# Out:
# {'APPL': 255.52, 'GOOGL': 333.33, 'TSLA': 437.43}

# %% [markdown]
# # Comment avoir les données boursières ?
# # En effet on ne va pas recopier à la main les dictionnaires.

# %%
# DONC on utilise les packages
! pip install yfinance
# YAHOO FINANCE
! pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python3 -m pip install --upgrade pip
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 55.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 72.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 59.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 104.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0
# [notice] To update, run: python3 -m pip install --upgrade pip

# %% [markdown]
# # La structure d'un projet python :
# Une cellule ou l'on importe tous les packages
# comme ça on une overview des dépendances

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ticker = "AAPL"

# %%
# Pour prendre les données du package yfinance on utilise
# Une fonction qui est def dans ce package pour extraire la donnée
data = yf.download(ticker, start="2020-01-01", progress=False)

# %%
data
# Out:
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2020-01-02   72.468246   72.528566   71.223244   71.476585  135480400
# 2020-01-03   71.763733   72.523762   71.539345   71.696175  146322800
# 2020-01-06   72.335564   72.374169   70.634547   70.885479  118387200
# 2020-01-07   71.995346   72.600952   71.775781   72.345197  108872000
# 2020-01-08   73.153481   73.455080   71.698566   71.698566  132079200
# ...                ...         ...         ...         ...        ...
# 2026-01-26  255.410004  256.559998  249.800003  251.479996   55969200
# 2026-01-27  258.269989  261.950012  258.209991  259.170013   49648300
# 2026-01-28  256.440002  258.859985  254.509995  257.649994   41288000
# 2026-01-29  258.279999  259.649994  254.410004  258.000000   67253000
# 2026-01-30  259.480011  261.899994  252.179993  255.169998   92352600
#
# [1528 rows x 5 columns]

# %%
data.head()
# fonction pour voir les 5 premières lignes du dataset
# Out:
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-01-02  72.468246  72.528566  71.223244  71.476585  135480400
# 2020-01-03  71.763733  72.523762  71.539345  71.696175  146322800
# 2020-01-06  72.335564  72.374169  70.634547  70.885479  118387200
# 2020-01-07  71.995346  72.600952  71.775781  72.345197  108872000
# 2020-01-08  73.153481  73.455080  71.698566  71.698566  132079200

# %%
data.tail() 
# fonction pour voir les 5 dernières lignes du dataset
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2026-01-26  255.410004  256.559998  249.800003  251.479996  55969200
# 2026-01-27  258.269989  261.950012  258.209991  259.170013  49648300
# 2026-01-28  256.440002  258.859985  254.509995  257.649994  41288000
# 2026-01-29  258.279999  259.649994  254.410004  258.000000  67253000
# 2026-01-30  259.480011  261.899994  252.179993  255.169998  92352600

# %% [markdown]
# # Financial specific
# yfinance, pypfopt, empyrical, riskk-it
# pandas, numpy, scipy
# scikit-learn, tensorflow, prophet, arch

# %%
# 1 Télécharger les données depuis 2020
ticker = "AAPL"
data = yf.download(ticker, start="2020-01-01", auto_adjust=False)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# 2. Calculer les rendements journaliers (Daily Returns)
# On utilise dele 'Adj Close' (Prix ajusté au dividende/splits)
data['Returns']=data['Adj Close'].pct_change()

# %%
# 3 Calculer la volatilité et le rendement moyen (Annualisés)
# il y a environ 252 jours de trading par an
mean_return_daily = data['Returns'].mean()
volatility_daily = data['Returns'].std()

annualized_return = mean_return_daily * 252
annualized_volatility = volatility_daily * np.sqrt(252)

# %%
# 4 Calcul du Ratio de Sharpe (Supposons taux sans risque = 0)
sharpe_ratio = annualized_return / annualized_volatility

print(f"---Analyse pour (ticker) {ticker}---")
print(f"Rendement annuel : {annualized_return:.2%}")
print(f"Volatilité annuelle : {annualized_volatility:.2%}")
print(f"Ratio de Sharpe : {sharpe_ratio:.2f}")

# interprétation simple : un sharpe > 1 est considéré comme bon
# Out:
# ---Analyse pour (ticker) AAPL---
# Rendement annuel : 26.06%
# Volatilité annuelle : 31.69%
# Ratio de Sharpe : 0.82

# %%
# plot it
plt.figure(figsize=(10,6))
plt.plot(data['Close'], label='AAPL Close Price')
plt.title('AAPL Close Price Over Time')
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')
